# %% [markdown]
# In this notebook I am going to cover the processing of cleaning and formatting a specific dataset for EMADE.

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

import shutil
import gzip

import os
import re
import math

# %% [markdown]
# We will start by importing all the libraries we will need. The most important libraries are numpy and pandas because we will use their data types to store and manipulate our dataset.
#
# Note: Make sure you have nltk's corpus downloaded. You can check by running nltk.download() in a Python shell.

# %% [markdown]
# Next, we will import our dataset into a pandas dataframe object.

# %%
data = pd.read_csv("datasets/winemag-data_first150k.csv")

# Print first 5 examples
print(data.head())
print(data.shape)

# remove all rows except for the first 25,000
data = data.drop(data.index[25000:])
print(data.shape)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude
# (150930, 10)
# (25000, 10)

# %% [markdown]
# The original link to the dataset can be found here: https://www.kaggle.com/zynicide/wine-reviews
#
# However, I removed the index column from the csv in Excel.
#
# The dataset consists of 10 features. Most of these are string values, which machine learning algorithms and data transformations will not accept. The dataset also has columns with missing values. We will either have to remove those columns or replace the missing values.
#
# We also cut the dataset size down to 25,000 examples to reduce the size of our final dataset and RAM usage.
#
# Note: if your computer does not have at least 8 GB of RAM, you might need to reduce the size of the data even more

# %% [markdown]
# Next, we will separate a column for labels and modify its values.

# %%
labels = data[["price"]]
print(labels.shape)

# Fill in all missing values with mean of column
labels = labels.fillna(labels.mean())

# Set all values greater or equal to 50 to 1
labels.loc[labels.price >= 50, 'price'] = 1
labels.loc[labels.price != 1, 'price'] = 0
# Out:
# (25000, 1)

# %% [markdown]
# In this case, we will choose to classify whether a wine has a price greater than or equal to 50. It is important to learn how to recognize potential labels and classification problems when you find a dataset. Most datasets will not have pre-defined labels and even those with labels you can tweak into a different problem.
#
# We also fill in the missing price values with the mean of all price values. There are many different methods of dealing with missing values. You could remove all missing value rows or replace missing values with the median instead.

# %% [markdown]
# Next, we will remove irrelevant and/or unuseful features.

# %%
data = data.drop("price", axis=1)
data = data.drop("region_2", axis=1)
data = data.drop("winery", axis=1)
data = data.drop("designation", axis=1)

# %% [markdown]
# I removed these features for a specific reason. Price needs to be removed because we will add it back as labels later. Region 2 is similar enough to region_1 to not add useful information. Winery and designation have too many unique values.
#
# When we one-hot encode some of our features in the next section, too many unique values will matter. If most of the strings in a feature are unique, we get very little useful or relevant information and only make the dimensions of our data unnecessarily large. This also applies to region 2. We do not want to double our dimensions with overlapping information.

# %% [markdown]
# Next, we will one-hot encoding on our remaining string features to extract relevant information from them.

# %%
data = pd.get_dummies(data, columns=["country", "province", "variety", "region_1"])

# %% [markdown]
# An explanation of one-hot encoding can be found here: https://www.quora.com/What-is-one-hot-encoding-and-when-is-it-used-in-data-science

# %% [markdown]
# Next, we will separate the descriptions column and clean up the text data. One-hot encoding does not work well on columns with unique sentences or paragraphs because all of the items in the column will end up being unique.

# %%
text = data[["description"]].values
data = data.drop("description", axis=1)

text_list = []
for i in text:
    text_list.append(i[0])
    
# Alternative
# text = text.tolist()
# text = [i[0] for i in text]
    
# For debugging
print(text_list[0])
count = 0

stemmer = PorterStemmer()

for text in text_list:
    count += 1
    text = text.lower()
    text = re.sub('[!@#$.,?]', '', text)
    words = text.split(" ")
    words = [word for word in words if word not in stopwords.words('english')]
    words = [stemmer.stem(word) for word in words]
    text = " ".join(words)
    print("line " + str(count) + " processed")
# Out:
# This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.
# line 1 processed
# line 2 processed
# line 3 processed
# line 4 processed
# line 5 processed
# line 6 processed
# line 7 processed
# line 8 processed
# line 9 processed
# line 10 processed
# line 11 processed
# line 12 processed
# line 13 processed
# line 14 processed
# line 15 processed
# line 16 processed
# line 17 processed
# line 18 processed
# line 19 processed
# line 20 processed
# line 21 processed
# line 22 processed
# line 23 processed
# line 24 processed
# line 25 processed
# line 26 processed
# line 27 processed
# line 28 processed
# line 29 processed
# line 30 processed
# line 31 processed
# line 32 processed
# line 33 processed
# line 34 processed
# line 35 processed
# line 36 processed
# line 37 processed
# line 38 processed
# line 39 processed
# line 40 processed
# line 41 processed
# line 42 processed
# line 43 processed
# line 44 processed
# line 45 processed
# line 46 processed
# line 47 processed
# line 48 processed
# line 49 processed
# line 50 processed
# line 51 processed
# line 52 processed
# line 53 processed
# line 54 processed
# line 55 processed
# line 56 processed
# line 57 processed
# line 58 processed
# line 59 processed
# line 60 processed
# line 61 processed
# line 62 processed
# line 63 processed
# line 64 processed
# line 65 processed
# line 66 processed
# line 67 processed
# line 68 processed
# line 69 processed
# line 70 processed
# line 71 processed
# line 72 processed
# line 73 processed
# line 74 processed
# line 75 processed
# line 76 processed
# line 77 processed
# line 78 processed
# line 79 processed
# line 80 processed
# line 81 processed
# line 82 processed
# line 83 processed
# line 84 processed
# line 85 processed
# line 86 processed
# line 87 processed
# line 88 processed
# line 89 processed
# line 90 processed
# line 91 processed
# line 92 processed
# line 93 processed
# line 94 processed
# line 95 processed
# line 96 processed
# line 97 processed
# line 98 processed
# line 99 processed
# line 100 processed
# line 101 processed
# line 102 processed
# line 103 processed
# line 104 processed
# line 105 processed
# line 106 processed
# line 107 processed
# line 108 processed
# line 109 processed
# line 110 processed
# line 111 processed
# line 112 processed
# line 113 processed
# line 114 processed
# line 115 processed
# line 116 processed
# line 117 processed
# line 118 processed
# line 119 processed
# line 120 processed
# line 121 processed
# line 122 processed
# line 123 processed
# line 124 processed
# line 125 processed
# line 126 processed
# line 127 processed
# line 128 processed
# line 129 processed
# line 130 processed
# line 131 processed
# line 132 processed
# line 133 processed
# line 134 processed
# line 135 processed
# line 136 processed
# line 137 processed
# line 138 processed
# line 139 processed
# line 140 processed
# line 141 processed
# line 142 processed
# line 143 processed
# line 144 processed
# line 145 processed
# line 146 processed
# line 147 processed
# line 148 processed
# line 149 processed
# line 150 processed
# line 151 processed
# line 152 processed
# line 153 processed
# line 154 processed
# line 155 processed
# line 156 processed
# line 157 processed
# line 158 processed
# line 159 processed
# line 160 processed
# line 161 processed
# line 162 processed
# line 163 processed
# line 164 processed
# line 165 processed
# line 166 processed
# line 167 processed
# line 168 processed
# line 169 processed
# line 170 processed
# line 171 processed
# line 172 processed
# line 173 processed
# line 174 processed
# line 175 processed
# line 176 processed
# line 177 processed
# line 178 processed
# line 179 processed
# line 180 processed
# line 181 processed
# line 182 processed
# line 183 processed
# line 184 processed
# line 185 processed
# line 186 processed
# line 187 processed
# line 188 processed
# line 189 processed
# line 190 processed
# line 191 processed
# line 192 processed
# line 193 processed
# line 194 processed
# line 195 processed
# line 196 processed
# line 197 processed
# line 198 processed
# line 199 processed
# line 200 processed
# line 201 processed
# line 202 processed
# line 203 processed
# line 204 processed
# line 205 processed
# line 206 processed
# line 207 processed
# line 208 processed
# line 209 processed
# line 210 processed
# line 211 processed
# line 212 processed
# line 213 processed
# line 214 processed
# line 215 processed
# line 216 processed
# line 217 processed
# line 218 processed
# line 219 processed
# line 220 processed
# line 221 processed
# line 222 processed
# line 223 processed
# line 224 processed
# line 225 processed
# line 226 processed
# line 227 processed
# line 228 processed
# line 229 processed
# line 230 processed
# line 231 processed
# line 232 processed
# line 233 processed
# line 234 processed
# line 235 processed
# line 236 processed
# line 237 processed
# line 238 processed
# line 239 processed
# line 240 processed
# line 241 processed
# line 242 processed
# line 243 processed
# line 244 processed
# line 245 processed
# line 246 processed
# line 247 processed
# line 248 processed
# line 249 processed
# line 250 processed
# line 251 processed
# line 252 processed
# line 253 processed
# line 254 processed
# line 255 processed
# line 256 processed
# line 257 processed
# line 258 processed
# line 259 processed
# line 260 processed
# line 261 processed
# line 262 processed
# line 263 processed
# line 264 processed
# line 265 processed
# line 266 processed
# line 267 processed
# line 268 processed
# line 269 processed
# line 270 processed
# line 271 processed
# line 272 processed
# line 273 processed
# line 274 processed
# line 275 processed
# line 276 processed
# line 277 processed
# line 278 processed
# line 279 processed
# line 280 processed
# line 281 processed
# line 282 processed
# line 283 processed
# line 284 processed
# line 285 processed
# line 286 processed
# line 287 processed
# line 288 processed
# line 289 processed
# line 290 processed
# line 291 processed
# line 292 processed
# line 293 processed
# line 294 processed
# line 295 processed
# line 296 processed
# line 297 processed
# line 298 processed
# line 299 processed
# line 300 processed
# line 301 processed
# line 302 processed
# line 303 processed
# line 304 processed
# line 305 processed
# line 306 processed
# line 307 processed
# line 308 processed
# line 309 processed
# line 310 processed
# line 311 processed
# line 312 processed
# line 313 processed
# line 314 processed
# line 315 processed
# line 316 processed
# line 317 processed
# line 318 processed
# line 319 processed
# line 320 processed
# line 321 processed
# line 322 processed
# line 323 processed
# line 324 processed
# line 325 processed
# line 326 processed
# line 327 processed
# line 328 processed
# line 329 processed
# line 330 processed
# line 331 processed
# line 332 processed
# line 333 processed
# line 334 processed
# line 335 processed
# line 336 processed
# line 337 processed
# line 338 processed
# line 339 processed
# line 340 processed
# line 341 processed
# line 342 processed
# line 343 processed
# line 344 processed
# line 345 processed
# line 346 processed
# line 347 processed
# line 348 processed
# line 349 processed
# line 350 processed
# line 351 processed
# line 352 processed
# line 353 processed
# line 354 processed
# line 355 processed
# line 356 processed
# line 357 processed
# line 358 processed
# line 359 processed
# line 360 processed
# line 361 processed
# line 362 processed
# line 363 processed
# line 364 processed
# line 365 processed
# line 366 processed
# line 367 processed
# line 368 processed
# line 369 processed
# line 370 processed
# line 371 processed
# line 372 processed
# line 373 processed
# line 374 processed
# line 375 processed
# line 376 processed
# line 377 processed
# line 378 processed
# line 379 processed
# line 380 processed
# line 381 processed
# line 382 processed
# line 383 processed
# line 384 processed
# line 385 processed
# line 386 processed
# line 387 processed
# line 388 processed
# line 389 processed
# line 390 processed
# line 391 processed
# line 392 processed
# line 393 processed
# line 394 processed
# line 395 processed
# line 396 processed
# line 397 processed
# line 398 processed
# line 399 processed
# line 400 processed
# line 401 processed
# line 402 processed
# line 403 processed
# line 404 processed
# line 405 processed
# line 406 processed
# line 407 processed
# line 408 processed
# line 409 processed
# line 410 processed
# line 411 processed
# line 412 processed
# line 413 processed
# line 414 processed
# line 415 processed
# line 416 processed
# line 417 processed
# line 418 processed
# line 419 processed
# line 420 processed
# line 421 processed
# line 422 processed
# line 423 processed
# line 424 processed
# line 425 processed
# line 426 processed
# line 427 processed
# line 428 processed
# line 429 processed
# line 430 processed
# line 431 processed
# line 432 processed
# line 433 processed
# line 434 processed
# line 435 processed
# line 436 processed
# line 437 processed
# line 438 processed
# line 439 processed
# line 440 processed
# line 441 processed
# line 442 processed
# line 443 processed
# line 444 processed
# line 445 processed
# line 446 processed
# line 447 processed
# line 448 processed
# line 449 processed
# line 450 processed
# line 451 processed
# line 452 processed
# line 453 processed
# line 454 processed
# line 455 processed
# line 456 processed
# line 457 processed
# line 458 processed
# line 459 processed
# line 460 processed
# line 461 processed
# line 462 processed
# line 463 processed
# line 464 processed
# line 465 processed
# line 466 processed
# line 467 processed
# line 468 processed
# line 469 processed
# line 470 processed
# line 471 processed
# line 472 processed
# line 473 processed
# line 474 processed
# line 475 processed
# line 476 processed
# line 477 processed
# line 478 processed
# line 479 processed
# line 480 processed
# line 481 processed
# line 482 processed
# line 483 processed
# line 484 processed
# line 485 processed
# line 486 processed
# line 487 processed
# line 488 processed
# line 489 processed
# line 490 processed
# line 491 processed
# line 492 processed
# line 493 processed
# line 494 processed
# line 495 processed
# line 496 processed
# line 497 processed
# line 498 processed
# line 499 processed
# line 500 processed
# line 501 processed
# line 502 processed
# line 503 processed
# line 504 processed
# line 505 processed
# line 506 processed
# line 507 processed
# line 508 processed
# line 509 processed
# line 510 processed
# line 511 processed
# line 512 processed
# line 513 processed
# line 514 processed
# line 515 processed
# line 516 processed
# line 517 processed
# line 518 processed
# line 519 processed
# line 520 processed
# line 521 processed
# line 522 processed
# line 523 processed
# line 524 processed
# line 525 processed
# line 526 processed
# line 527 processed
# line 528 processed
# line 529 processed
# line 530 processed
# line 531 processed
# line 532 processed
# line 533 processed
# line 534 processed
# line 535 processed
# line 536 processed
# line 537 processed
# line 538 processed
# line 539 processed
# line 540 processed
# line 541 processed
# line 542 processed
# line 543 processed
# line 544 processed
# line 545 processed
# line 546 processed
# line 547 processed
# line 548 processed
# line 549 processed
# line 550 processed
# line 551 processed
# line 552 processed
# line 553 processed
# line 554 processed
# line 555 processed
# line 556 processed
# line 557 processed
# line 558 processed
# line 559 processed
# line 560 processed
# line 561 processed
# line 562 processed
# line 563 processed
# line 564 processed
# line 565 processed
# line 566 processed
# line 567 processed
# line 568 processed
# line 569 processed
# line 570 processed
# line 571 processed
# line 572 processed
# line 573 processed
# line 574 processed
# line 575 processed
# line 576 processed
# line 577 processed
# line 578 processed
# line 579 processed
# line 580 processed
# line 581 processed
# line 582 processed
# line 583 processed
# line 584 processed
# line 585 processed
# line 586 processed
# line 587 processed
# line 588 processed
# line 589 processed
# line 590 processed
# line 591 processed
# line 592 processed
# line 593 processed
# line 594 processed
# line 595 processed
# line 596 processed
# line 597 processed
# line 598 processed
# line 599 processed
# line 600 processed
# line 601 processed
# line 602 processed
# line 603 processed
# line 604 processed
# line 605 processed
# line 606 processed
# line 607 processed
# line 608 processed
# line 609 processed
# line 610 processed
# line 611 processed
# line 612 processed
# line 613 processed
# line 614 processed
# line 615 processed
# line 616 processed
# line 617 processed
# line 618 processed
# line 619 processed
# line 620 processed
# line 621 processed
# line 622 processed
# line 623 processed
# line 624 processed
# line 625 processed
# line 626 processed
# line 627 processed
# line 628 processed
# line 629 processed
# line 630 processed
# line 631 processed
# line 632 processed
# line 633 processed
# line 634 processed
# line 635 processed
# line 636 processed
# line 637 processed
# line 638 processed
# line 639 processed
# line 640 processed
# line 641 processed
# line 642 processed
# line 643 processed
# line 644 processed
# line 645 processed
# line 646 processed
# line 647 processed
# line 648 processed
# line 649 processed
# line 650 processed
# line 651 processed
# line 652 processed
# line 653 processed
# line 654 processed
# line 655 processed
# line 656 processed
# line 657 processed
# line 658 processed
# line 659 processed
# line 660 processed
# line 661 processed
# line 662 processed
# line 663 processed
# line 664 processed
# line 665 processed
# line 666 processed
# line 667 processed
# line 668 processed
# line 669 processed
# line 670 processed
# line 671 processed
# line 672 processed
# line 673 processed
# line 674 processed
# line 675 processed
# line 676 processed
# line 677 processed
# line 678 processed
# line 679 processed
# line 680 processed
# line 681 processed
# line 682 processed
# line 683 processed
# line 684 processed
# line 685 processed
# line 686 processed
# line 687 processed
# line 688 processed
# line 689 processed
# line 690 processed
# line 691 processed
# line 692 processed
# line 693 processed
# line 694 processed
# line 695 processed
# line 696 processed
# line 697 processed
# line 698 processed
# line 699 processed
# line 700 processed
# line 701 processed
# line 702 processed
# line 703 processed
# line 704 processed
# line 705 processed
# line 706 processed
# line 707 processed
# line 708 processed
# line 709 processed
# line 710 processed
# line 711 processed
# line 712 processed
# line 713 processed
# line 714 processed
# line 715 processed
# line 716 processed
# line 717 processed
# line 718 processed
# line 719 processed
# line 720 processed
# line 721 processed
# line 722 processed
# line 723 processed
# line 724 processed
# line 725 processed
# line 726 processed
# line 727 processed
# line 728 processed
# line 729 processed
# line 730 processed
# line 731 processed
# line 732 processed
# line 733 processed
# line 734 processed
# line 735 processed
# line 736 processed
# line 737 processed
# line 738 processed
# line 739 processed
# line 740 processed
# line 741 processed
# line 742 processed
# line 743 processed
# line 744 processed
# line 745 processed
# line 746 processed
# line 747 processed
# line 748 processed
# line 749 processed
# line 750 processed
# line 751 processed
# line 752 processed
# line 753 processed
# line 754 processed
# line 755 processed
# line 756 processed
# line 757 processed
# line 758 processed
# line 759 processed
# line 760 processed
# line 761 processed
# line 762 processed
# line 763 processed
# line 764 processed
# line 765 processed
# line 766 processed
# line 767 processed
# line 768 processed
# line 769 processed
# line 770 processed
# line 771 processed
# line 772 processed
# line 773 processed
# line 774 processed
# line 775 processed
# line 776 processed
# line 777 processed
# line 778 processed
# line 779 processed
# line 780 processed
# line 781 processed
# line 782 processed
# line 783 processed
# line 784 processed
# line 785 processed
# line 786 processed
# line 787 processed
# line 788 processed
# line 789 processed
# line 790 processed
# line 791 processed
# line 792 processed
# line 793 processed
# line 794 processed
# line 795 processed
# line 796 processed
# line 797 processed
# line 798 processed
# line 799 processed
# line 800 processed
# line 801 processed
# line 802 processed
# line 803 processed
# line 804 processed
# line 805 processed
# line 806 processed
# line 807 processed
# line 808 processed
# line 809 processed
# line 810 processed
# line 811 processed
# line 812 processed
# line 813 processed
# line 814 processed
# line 815 processed
# line 816 processed
# line 817 processed
# line 818 processed
# line 819 processed
# line 820 processed
# line 821 processed
# line 822 processed
# line 823 processed
# line 824 processed
# line 825 processed
# line 826 processed
# line 827 processed
# line 828 processed
# line 829 processed
# line 830 processed
# line 831 processed
# line 832 processed
# line 833 processed
# line 834 processed
# line 835 processed
# line 836 processed
# line 837 processed
# line 838 processed
# line 839 processed
# line 840 processed
# line 841 processed
# line 842 processed
# line 843 processed
# line 844 processed
# line 845 processed
# line 846 processed
# line 847 processed
# line 848 processed
# line 849 processed
# line 850 processed
# line 851 processed
# line 852 processed
# line 853 processed
# line 854 processed
# line 855 processed
# line 856 processed
# line 857 processed
# line 858 processed
# line 859 processed
# line 860 processed
# line 861 processed
# line 862 processed
# line 863 processed
# line 864 processed
# line 865 processed
# line 866 processed
# line 867 processed
# line 868 processed
# line 869 processed
# line 870 processed
# line 871 processed
# line 872 processed
# line 873 processed
# line 874 processed
# line 875 processed
# line 876 processed
# line 877 processed
# line 878 processed
# line 879 processed
# line 880 processed
# line 881 processed
# line 882 processed
# line 883 processed
# line 884 processed
# line 885 processed
# line 886 processed
# line 887 processed
# line 888 processed
# line 889 processed
# line 890 processed
# line 891 processed
# line 892 processed
# line 893 processed
# line 894 processed
# line 895 processed
# line 896 processed
# line 897 processed
# line 898 processed
# line 899 processed
# line 900 processed
# line 901 processed
# line 902 processed
# line 903 processed
# line 904 processed
# line 905 processed
# line 906 processed
# line 907 processed
# line 908 processed
# line 909 processed
# line 910 processed
# line 911 processed
# line 912 processed
# line 913 processed
# line 914 processed
# line 915 processed
# line 916 processed
# line 917 processed
# line 918 processed
# line 919 processed
# line 920 processed
# line 921 processed
# line 922 processed
# line 923 processed
# line 924 processed
# line 925 processed
# line 926 processed
# line 927 processed
# line 928 processed
# line 929 processed
# line 930 processed
# line 931 processed
# line 932 processed
# line 933 processed
# line 934 processed
# line 935 processed
# line 936 processed
# line 937 processed
# line 938 processed
# line 939 processed
# line 940 processed
# line 941 processed
# line 942 processed
# line 943 processed
# line 944 processed
# line 945 processed
# line 946 processed
# line 947 processed
# line 948 processed
# line 949 processed
# line 950 processed
# line 951 processed
# line 952 processed
# line 953 processed
# line 954 processed
# line 955 processed
# line 956 processed
# line 957 processed
# line 958 processed
# line 959 processed
# line 960 processed
# line 961 processed
# line 962 processed
# line 963 processed
# line 964 processed
# line 965 processed
# line 966 processed
# line 967 processed
# line 968 processed
# line 969 processed
# line 970 processed
# line 971 processed
# line 972 processed
# line 973 processed
# line 974 processed
# line 975 processed
# line 976 processed
# line 977 processed
# line 978 processed
# line 979 processed
# line 980 processed
# line 981 processed
# line 982 processed
# line 983 processed
# line 984 processed
# line 985 processed
# line 986 processed
# line 987 processed
# line 988 processed
# line 989 processed
# line 990 processed
# line 991 processed
# line 992 processed
# line 993 processed
# line 994 processed
# line 995 processed
# line 996 processed
# line 997 processed
# line 998 processed
# line 999 processed
# line 1000 processed
# line 1001 processed
# line 1002 processed
# line 1003 processed
# line 1004 processed
# line 1005 processed
# line 1006 processed
# line 1007 processed
# line 1008 processed
# line 1009 processed
# line 1010 processed
# line 1011 processed
# line 1012 processed
# line 1013 processed
# line 1014 processed
# line 1015 processed
# line 1016 processed
# line 1017 processed
# line 1018 processed
# line 1019 processed
# line 1020 processed
# line 1021 processed
# line 1022 processed
# line 1023 processed
# line 1024 processed
# line 1025 processed
# line 1026 processed
# line 1027 processed
# line 1028 processed
# line 1029 processed
# line 1030 processed
# line 1031 processed
# line 1032 processed
# line 1033 processed
# line 1034 processed
# line 1035 processed
# line 1036 processed
# line 1037 processed
# line 1038 processed
# line 1039 processed
# line 1040 processed
# line 1041 processed
# line 1042 processed
# line 1043 processed
# line 1044 processed
# line 1045 processed
# line 1046 processed
# line 1047 processed
# line 1048 processed
# line 1049 processed
# line 1050 processed
# line 1051 processed
# line 1052 processed
# line 1053 processed
# line 1054 processed
# line 1055 processed
# line 1056 processed
# line 1057 processed
# line 1058 processed
# line 1059 processed
# line 1060 processed
# line 1061 processed
# line 1062 processed
# line 1063 processed
# line 1064 processed
# line 1065 processed
# line 1066 processed
# line 1067 processed
# line 1068 processed
# line 1069 processed
# line 1070 processed
# line 1071 processed
# line 1072 processed
# line 1073 processed
# line 1074 processed
# line 1075 processed
# line 1076 processed
# line 1077 processed
# line 1078 processed
# line 1079 processed
# line 1080 processed
# line 1081 processed
# line 1082 processed
# line 1083 processed
# line 1084 processed
# line 1085 processed
# line 1086 processed
# line 1087 processed
# line 1088 processed
# line 1089 processed
# line 1090 processed
# line 1091 processed
# line 1092 processed
# line 1093 processed
# line 1094 processed
# line 1095 processed
# line 1096 processed
# line 1097 processed
# line 1098 processed
# line 1099 processed
# line 1100 processed
# line 1101 processed
# line 1102 processed
# line 1103 processed
# line 1104 processed
# line 1105 processed
# line 1106 processed
# line 1107 processed
# line 1108 processed
# line 1109 processed
# line 1110 processed
# line 1111 processed
# line 1112 processed
# line 1113 processed
# line 1114 processed
# line 1115 processed
# line 1116 processed
# line 1117 processed
# line 1118 processed
# line 1119 processed
# line 1120 processed
# line 1121 processed
# line 1122 processed
# line 1123 processed
# line 1124 processed
# line 1125 processed
# line 1126 processed
# line 1127 processed
# line 1128 processed
# line 1129 processed
# line 1130 processed
# line 1131 processed
# line 1132 processed
# line 1133 processed
# line 1134 processed
# line 1135 processed
# line 1136 processed
# line 1137 processed
# line 1138 processed
# line 1139 processed
# line 1140 processed
# line 1141 processed
# line 1142 processed
# line 1143 processed
# line 1144 processed
# line 1145 processed
# line 1146 processed
# line 1147 processed
# line 1148 processed
# line 1149 processed
# line 1150 processed
# line 1151 processed
# line 1152 processed
# line 1153 processed
# line 1154 processed
# line 1155 processed
# line 1156 processed
# line 1157 processed
# line 1158 processed
# line 1159 processed
# line 1160 processed
# line 1161 processed
# line 1162 processed
# line 1163 processed
# line 1164 processed
# line 1165 processed
# line 1166 processed
# line 1167 processed
# line 1168 processed
# line 1169 processed
# line 1170 processed
# line 1171 processed
# line 1172 processed
# line 1173 processed
# line 1174 processed
# line 1175 processed
# line 1176 processed
# line 1177 processed
# line 1178 processed
# line 1179 processed
# line 1180 processed
# line 1181 processed
# line 1182 processed
# line 1183 processed
# line 1184 processed
# line 1185 processed
# line 1186 processed
# line 1187 processed
# line 1188 processed
# line 1189 processed
# line 1190 processed
# line 1191 processed
# line 1192 processed
# line 1193 processed
# line 1194 processed
# line 1195 processed
# line 1196 processed
# line 1197 processed
# line 1198 processed
# line 1199 processed
# line 1200 processed
# line 1201 processed
# line 1202 processed
# line 1203 processed
# line 1204 processed
# line 1205 processed
# line 1206 processed
# line 1207 processed
# line 1208 processed
# line 1209 processed
# line 1210 processed
# line 1211 processed
# line 1212 processed
# line 1213 processed
# line 1214 processed
# line 1215 processed
# line 1216 processed
# line 1217 processed
# line 1218 processed
# line 1219 processed
# line 1220 processed
# line 1221 processed
# line 1222 processed
# line 1223 processed
# line 1224 processed
# line 1225 processed
# line 1226 processed
# line 1227 processed
# line 1228 processed
# line 1229 processed
# line 1230 processed
# line 1231 processed
# line 1232 processed
# line 1233 processed
# line 1234 processed
# line 1235 processed
# line 1236 processed
# line 1237 processed
# line 1238 processed
# line 1239 processed
# line 1240 processed
# line 1241 processed
# line 1242 processed
# line 1243 processed
# line 1244 processed
# line 1245 processed
# line 1246 processed
# line 1247 processed
# line 1248 processed
# line 1249 processed
# line 1250 processed
# line 1251 processed
# line 1252 processed
# line 1253 processed
# line 1254 processed
# line 1255 processed
# line 1256 processed
# line 1257 processed
# line 1258 processed
# line 1259 processed
# line 1260 processed
# line 1261 processed
# line 1262 processed
# line 1263 processed
# line 1264 processed
# line 1265 processed
# line 1266 processed
# line 1267 processed
# line 1268 processed
# line 1269 processed
# line 1270 processed
# line 1271 processed
# line 1272 processed
# line 1273 processed
# line 1274 processed
# line 1275 processed
# line 1276 processed
# line 1277 processed
# line 1278 processed
# line 1279 processed
# line 1280 processed
# line 1281 processed
# line 1282 processed
# line 1283 processed
# line 1284 processed
# line 1285 processed
# line 1286 processed
# line 1287 processed
# line 1288 processed
# line 1289 processed
# line 1290 processed
# line 1291 processed
# line 1292 processed
# line 1293 processed
# line 1294 processed
# line 1295 processed
# line 1296 processed
# line 1297 processed
# line 1298 processed
# line 1299 processed
# line 1300 processed
# line 1301 processed
# line 1302 processed
# line 1303 processed
# line 1304 processed
# line 1305 processed
# line 1306 processed
# line 1307 processed
# line 1308 processed
# line 1309 processed
# line 1310 processed
# line 1311 processed
# line 1312 processed
# line 1313 processed
# line 1314 processed
# line 1315 processed
# line 1316 processed
# line 1317 processed
# line 1318 processed
# line 1319 processed
# line 1320 processed
# line 1321 processed
# line 1322 processed
# line 1323 processed
# line 1324 processed
# line 1325 processed
# line 1326 processed
# line 1327 processed
# line 1328 processed
# line 1329 processed
# line 1330 processed
# line 1331 processed
# line 1332 processed
# line 1333 processed
# line 1334 processed
# line 1335 processed
# line 1336 processed
# line 1337 processed
# line 1338 processed
# line 1339 processed
# line 1340 processed
# line 1341 processed
# line 1342 processed
# line 1343 processed
# line 1344 processed
# line 1345 processed
# line 1346 processed
# line 1347 processed
# line 1348 processed
# line 1349 processed
# line 1350 processed
# line 1351 processed
# line 1352 processed
# line 1353 processed
# line 1354 processed
# line 1355 processed
# line 1356 processed
# line 1357 processed
# line 1358 processed
# line 1359 processed
# line 1360 processed
# line 1361 processed
# line 1362 processed
# line 1363 processed
# line 1364 processed
# line 1365 processed
# line 1366 processed
# line 1367 processed
# line 1368 processed
# line 1369 processed
# line 1370 processed
# line 1371 processed
# line 1372 processed
# line 1373 processed
# line 1374 processed
# line 1375 processed
# line 1376 processed
# line 1377 processed
# line 1378 processed
# line 1379 processed
# line 1380 processed
# line 1381 processed
# line 1382 processed
# line 1383 processed
# line 1384 processed
# line 1385 processed
# line 1386 processed
# line 1387 processed
# line 1388 processed
# line 1389 processed
# line 1390 processed
# line 1391 processed
# line 1392 processed
# line 1393 processed
# line 1394 processed
# line 1395 processed
# line 1396 processed
# line 1397 processed
# line 1398 processed
# line 1399 processed
# line 1400 processed
# line 1401 processed
# line 1402 processed
# line 1403 processed
# line 1404 processed
# line 1405 processed
# line 1406 processed
# line 1407 processed
# line 1408 processed
# line 1409 processed
# line 1410 processed
# line 1411 processed
# line 1412 processed
# line 1413 processed
# line 1414 processed
# line 1415 processed
# line 1416 processed
# line 1417 processed
# line 1418 processed
# line 1419 processed
# line 1420 processed
# line 1421 processed
# line 1422 processed
# line 1423 processed
# line 1424 processed
# line 1425 processed
# line 1426 processed
# line 1427 processed
# line 1428 processed
# line 1429 processed
# line 1430 processed
# line 1431 processed
# line 1432 processed
# line 1433 processed
# line 1434 processed
# line 1435 processed
# line 1436 processed
# line 1437 processed
# line 1438 processed
# line 1439 processed
# line 1440 processed
# line 1441 processed
# line 1442 processed
# line 1443 processed
# line 1444 processed
# line 1445 processed
# line 1446 processed
# line 1447 processed
# line 1448 processed
# line 1449 processed
# line 1450 processed
# line 1451 processed
# line 1452 processed
# line 1453 processed
# line 1454 processed
# line 1455 processed
# line 1456 processed
# line 1457 processed
# line 1458 processed
# line 1459 processed
# line 1460 processed
# line 1461 processed
# line 1462 processed
# line 1463 processed
# line 1464 processed
# line 1465 processed
# line 1466 processed
# line 1467 processed
# line 1468 processed
# line 1469 processed
# line 1470 processed
# line 1471 processed
# line 1472 processed
# line 1473 processed
# line 1474 processed
# line 1475 processed
# line 1476 processed
# line 1477 processed
# line 1478 processed
# line 1479 processed
# line 1480 processed
# line 1481 processed
# line 1482 processed
# line 1483 processed
# line 1484 processed
# line 1485 processed
# line 1486 processed
# line 1487 processed
# line 1488 processed
# line 1489 processed
# line 1490 processed
# line 1491 processed
# line 1492 processed
# line 1493 processed
# line 1494 processed
# line 1495 processed
# line 1496 processed
# line 1497 processed
# line 1498 processed
# line 1499 processed
# line 1500 processed
# line 1501 processed
# line 1502 processed
# line 1503 processed
# line 1504 processed
# line 1505 processed
# line 1506 processed
# line 1507 processed
# line 1508 processed
# line 1509 processed
# line 1510 processed
# line 1511 processed
# line 1512 processed
# line 1513 processed
# line 1514 processed
# line 1515 processed
# line 1516 processed
# line 1517 processed
# line 1518 processed
# line 1519 processed
# line 1520 processed
# line 1521 processed
# line 1522 processed
# line 1523 processed
# line 1524 processed
# line 1525 processed
# line 1526 processed
# line 1527 processed
# line 1528 processed
# line 1529 processed
# line 1530 processed
# line 1531 processed
# line 1532 processed
# line 1533 processed
# line 1534 processed
# line 1535 processed
# line 1536 processed
# line 1537 processed
# line 1538 processed
# line 1539 processed
# line 1540 processed
# line 1541 processed
# line 1542 processed
# line 1543 processed
# line 1544 processed
# line 1545 processed
# line 1546 processed
# line 1547 processed
# line 1548 processed
# line 1549 processed
# line 1550 processed
# line 1551 processed
# line 1552 processed
# line 1553 processed
# line 1554 processed
# line 1555 processed
# line 1556 processed
# line 1557 processed
# line 1558 processed
# line 1559 processed
# line 1560 processed
# line 1561 processed
# line 1562 processed
# line 1563 processed
# line 1564 processed
# line 1565 processed
# line 1566 processed
# line 1567 processed
# line 1568 processed
# line 1569 processed
# line 1570 processed
# line 1571 processed
# line 1572 processed
# line 1573 processed
# line 1574 processed
# line 1575 processed
# line 1576 processed
# line 1577 processed
# line 1578 processed
# line 1579 processed
# line 1580 processed
# line 1581 processed
# line 1582 processed
# line 1583 processed
# line 1584 processed
# line 1585 processed
# line 1586 processed
# line 1587 processed
# line 1588 processed
# line 1589 processed
# line 1590 processed
# line 1591 processed
# line 1592 processed
# line 1593 processed
# line 1594 processed
# line 1595 processed
# line 1596 processed
# line 1597 processed
# line 1598 processed
# line 1599 processed
# line 1600 processed
# line 1601 processed
# line 1602 processed
# line 1603 processed
# line 1604 processed
# line 1605 processed
# line 1606 processed
# line 1607 processed
# line 1608 processed
# line 1609 processed
# line 1610 processed
# line 1611 processed
# line 1612 processed
# line 1613 processed
# line 1614 processed
# line 1615 processed
# line 1616 processed
# line 1617 processed
# line 1618 processed
# line 1619 processed
# line 1620 processed
# line 1621 processed
# line 1622 processed
# line 1623 processed
# line 1624 processed
# line 1625 processed
# line 1626 processed
# line 1627 processed
# line 1628 processed
# line 1629 processed
# line 1630 processed
# line 1631 processed
# line 1632 processed
# line 1633 processed
# line 1634 processed
# line 1635 processed
# line 1636 processed
# line 1637 processed
# line 1638 processed
# line 1639 processed
# line 1640 processed
# line 1641 processed
# line 1642 processed
# line 1643 processed
# line 1644 processed
# line 1645 processed
# line 1646 processed
# line 1647 processed
# line 1648 processed
# line 1649 processed
# line 1650 processed
# line 1651 processed
# line 1652 processed
# line 1653 processed
# line 1654 processed
# line 1655 processed
# line 1656 processed
# line 1657 processed
# line 1658 processed
# line 1659 processed
# line 1660 processed
# line 1661 processed
# line 1662 processed
# line 1663 processed
# line 1664 processed
# line 1665 processed
# line 1666 processed
# line 1667 processed
# line 1668 processed
# line 1669 processed
# line 1670 processed
# line 1671 processed
# line 1672 processed
# line 1673 processed
# line 1674 processed
# line 1675 processed
# line 1676 processed
# line 1677 processed
# line 1678 processed
# line 1679 processed
# line 1680 processed
# line 1681 processed
# line 1682 processed
# line 1683 processed
# line 1684 processed
# line 1685 processed
# line 1686 processed
# line 1687 processed
# line 1688 processed
# line 1689 processed
# line 1690 processed
# line 1691 processed
# line 1692 processed
# line 1693 processed
# line 1694 processed
# line 1695 processed
# line 1696 processed
# line 1697 processed
# line 1698 processed
# line 1699 processed
# line 1700 processed
# line 1701 processed
# line 1702 processed
# line 1703 processed
# line 1704 processed
# line 1705 processed
# line 1706 processed
# line 1707 processed
# line 1708 processed
# line 1709 processed
# line 1710 processed
# line 1711 processed
# line 1712 processed
# line 1713 processed
# line 1714 processed
# line 1715 processed
# line 1716 processed
# line 1717 processed
# line 1718 processed
# line 1719 processed
# line 1720 processed
# line 1721 processed
# line 1722 processed
# line 1723 processed
# line 1724 processed
# line 1725 processed
# line 1726 processed
# line 1727 processed
# line 1728 processed
# line 1729 processed
# line 1730 processed
# line 1731 processed
# line 1732 processed
# line 1733 processed
# line 1734 processed
# line 1735 processed
# line 1736 processed
# line 1737 processed
# line 1738 processed
# line 1739 processed
# line 1740 processed
# line 1741 processed
# line 1742 processed
# line 1743 processed
# line 1744 processed
# line 1745 processed
# line 1746 processed
# line 1747 processed
# line 1748 processed
# line 1749 processed
# line 1750 processed
# line 1751 processed
# line 1752 processed
# line 1753 processed
# line 1754 processed
# line 1755 processed
# line 1756 processed
# line 1757 processed
# line 1758 processed
# line 1759 processed
# line 1760 processed
# line 1761 processed
# line 1762 processed
# line 1763 processed
# line 1764 processed
# line 1765 processed
# line 1766 processed
# line 1767 processed
# line 1768 processed
# line 1769 processed
# line 1770 processed
# line 1771 processed
# line 1772 processed
# line 1773 processed
# line 1774 processed
# line 1775 processed
# line 1776 processed
# line 1777 processed
# line 1778 processed
# line 1779 processed
# line 1780 processed
# line 1781 processed
# line 1782 processed
# line 1783 processed
# line 1784 processed
# line 1785 processed
# line 1786 processed
# line 1787 processed
# line 1788 processed
# line 1789 processed
# line 1790 processed
# line 1791 processed
# line 1792 processed
# line 1793 processed
# line 1794 processed
# line 1795 processed
# line 1796 processed
# line 1797 processed
# line 1798 processed
# line 1799 processed
# line 1800 processed
# line 1801 processed
# line 1802 processed
# line 1803 processed
# line 1804 processed
# line 1805 processed
# line 1806 processed
# line 1807 processed
# line 1808 processed
# line 1809 processed
# line 1810 processed
# line 1811 processed
# line 1812 processed
# line 1813 processed
# line 1814 processed
# line 1815 processed
# line 1816 processed
# line 1817 processed
# line 1818 processed
# line 1819 processed
# line 1820 processed
# line 1821 processed
# line 1822 processed
# line 1823 processed
# line 1824 processed
# line 1825 processed
# line 1826 processed
# line 1827 processed
# line 1828 processed
# line 1829 processed
# line 1830 processed
# line 1831 processed
# line 1832 processed
# line 1833 processed
# line 1834 processed
# line 1835 processed
# line 1836 processed
# line 1837 processed
# line 1838 processed
# line 1839 processed
# line 1840 processed
# line 1841 processed
# line 1842 processed
# line 1843 processed
# line 1844 processed
# line 1845 processed
# line 1846 processed
# line 1847 processed
# line 1848 processed
# line 1849 processed
# line 1850 processed
# line 1851 processed
# line 1852 processed
# line 1853 processed
# line 1854 processed
# line 1855 processed
# line 1856 processed
# line 1857 processed
# line 1858 processed
# line 1859 processed
# line 1860 processed
# line 1861 processed
# line 1862 processed
# line 1863 processed
# line 1864 processed
# line 1865 processed
# line 1866 processed
# line 1867 processed
# line 1868 processed
# line 1869 processed
# line 1870 processed
# line 1871 processed
# line 1872 processed
# line 1873 processed
# line 1874 processed
# line 1875 processed
# line 1876 processed
# line 1877 processed
# line 1878 processed
# line 1879 processed
# line 1880 processed
# line 1881 processed
# line 1882 processed
# line 1883 processed
# line 1884 processed
# line 1885 processed
# line 1886 processed
# line 1887 processed
# line 1888 processed
# line 1889 processed
# line 1890 processed
# line 1891 processed
# line 1892 processed
# line 1893 processed
# line 1894 processed
# line 1895 processed
# line 1896 processed
# line 1897 processed
# line 1898 processed
# line 1899 processed
# line 1900 processed
# line 1901 processed
# line 1902 processed
# line 1903 processed
# line 1904 processed
# line 1905 processed
# line 1906 processed
# line 1907 processed
# line 1908 processed
# line 1909 processed
# line 1910 processed
# line 1911 processed
# line 1912 processed
# line 1913 processed
# line 1914 processed
# line 1915 processed
# line 1916 processed
# line 1917 processed
# line 1918 processed
# line 1919 processed
# line 1920 processed
# line 1921 processed
# line 1922 processed
# line 1923 processed
# line 1924 processed
# line 1925 processed
# line 1926 processed
# line 1927 processed
# line 1928 processed
# line 1929 processed
# line 1930 processed
# line 1931 processed
# line 1932 processed
# line 1933 processed
# line 1934 processed
# line 1935 processed
# line 1936 processed
# line 1937 processed
# line 1938 processed
# line 1939 processed
# line 1940 processed
# line 1941 processed
# line 1942 processed
# line 1943 processed
# line 1944 processed
# line 1945 processed
# line 1946 processed
# line 1947 processed
# line 1948 processed
# line 1949 processed
# line 1950 processed
# line 1951 processed
# line 1952 processed
# line 1953 processed
# line 1954 processed
# line 1955 processed
# line 1956 processed
# line 1957 processed
# line 1958 processed
# line 1959 processed
# line 1960 processed
# line 1961 processed
# line 1962 processed
# line 1963 processed
# line 1964 processed
# line 1965 processed
# line 1966 processed
# line 1967 processed
# line 1968 processed
# line 1969 processed
# line 1970 processed
# line 1971 processed
# line 1972 processed
# line 1973 processed
# line 1974 processed
# line 1975 processed
# line 1976 processed
# line 1977 processed
# line 1978 processed
# line 1979 processed
# line 1980 processed
# line 1981 processed
# line 1982 processed
# line 1983 processed
# line 1984 processed
# line 1985 processed
# line 1986 processed
# line 1987 processed
# line 1988 processed
# line 1989 processed
# line 1990 processed
# line 1991 processed
# line 1992 processed
# line 1993 processed
# line 1994 processed
# line 1995 processed
# line 1996 processed
# line 1997 processed
# line 1998 processed
# line 1999 processed
# line 2000 processed
# line 2001 processed
# line 2002 processed
# line 2003 processed
# line 2004 processed
# line 2005 processed
# line 2006 processed
# line 2007 processed
# line 2008 processed
# line 2009 processed
# line 2010 processed
# line 2011 processed
# line 2012 processed
# line 2013 processed
# line 2014 processed
# line 2015 processed
# line 2016 processed
# line 2017 processed
# line 2018 processed
# line 2019 processed
# line 2020 processed
# line 2021 processed
# line 2022 processed
# line 2023 processed
# line 2024 processed
# line 2025 processed
# line 2026 processed
# line 2027 processed
# line 2028 processed
# line 2029 processed
# line 2030 processed
# line 2031 processed
# line 2032 processed
# line 2033 processed
# line 2034 processed
# line 2035 processed
# line 2036 processed
# line 2037 processed
# line 2038 processed
# line 2039 processed
# line 2040 processed
# line 2041 processed
# line 2042 processed
# line 2043 processed
# line 2044 processed
# line 2045 processed
# line 2046 processed
# line 2047 processed
# line 2048 processed
# line 2049 processed
# line 2050 processed
# line 2051 processed
# line 2052 processed
# line 2053 processed
# line 2054 processed
# line 2055 processed
# line 2056 processed
# line 2057 processed
# line 2058 processed
# line 2059 processed
# line 2060 processed
# line 2061 processed
# line 2062 processed
# line 2063 processed
# line 2064 processed
# line 2065 processed
# line 2066 processed
# line 2067 processed
# line 2068 processed
# line 2069 processed
# line 2070 processed
# line 2071 processed
# line 2072 processed
# line 2073 processed
# line 2074 processed
# line 2075 processed
# line 2076 processed
# line 2077 processed
# line 2078 processed
# line 2079 processed
# line 2080 processed
# line 2081 processed
# line 2082 processed
# line 2083 processed
# line 2084 processed
# line 2085 processed
# line 2086 processed
# line 2087 processed
# line 2088 processed
# line 2089 processed
# line 2090 processed
# line 2091 processed
# line 2092 processed
# line 2093 processed
# line 2094 processed
# line 2095 processed
# line 2096 processed
# line 2097 processed
# line 2098 processed
# line 2099 processed
# line 2100 processed
# line 2101 processed
# line 2102 processed
# line 2103 processed
# line 2104 processed
# line 2105 processed
# line 2106 processed
# line 2107 processed
# line 2108 processed
# line 2109 processed
# line 2110 processed
# line 2111 processed
# line 2112 processed
# line 2113 processed
# line 2114 processed
# line 2115 processed
# line 2116 processed
# line 2117 processed
# line 2118 processed
# line 2119 processed
# line 2120 processed
# line 2121 processed
# line 2122 processed
# line 2123 processed
# line 2124 processed
# line 2125 processed
# line 2126 processed
# line 2127 processed
# line 2128 processed
# line 2129 processed
# line 2130 processed
# line 2131 processed
# line 2132 processed
# line 2133 processed
# line 2134 processed
# line 2135 processed
# line 2136 processed
# line 2137 processed
# line 2138 processed
# line 2139 processed
# line 2140 processed
# line 2141 processed
# line 2142 processed
# line 2143 processed
# line 2144 processed
# line 2145 processed
# line 2146 processed
# line 2147 processed
# line 2148 processed
# line 2149 processed
# line 2150 processed
# line 2151 processed
# line 2152 processed
# line 2153 processed
# line 2154 processed
# line 2155 processed
# line 2156 processed
# line 2157 processed
# line 2158 processed
# line 2159 processed
# line 2160 processed
# line 2161 processed
# line 2162 processed
# line 2163 processed
# line 2164 processed
# line 2165 processed
# line 2166 processed
# line 2167 processed
# line 2168 processed
# line 2169 processed
# line 2170 processed
# line 2171 processed
# line 2172 processed
# line 2173 processed
# line 2174 processed
# line 2175 processed
# line 2176 processed
# line 2177 processed
# line 2178 processed
# line 2179 processed
# line 2180 processed
# line 2181 processed
# line 2182 processed
# line 2183 processed
# line 2184 processed
# line 2185 processed
# line 2186 processed
# line 2187 processed
# line 2188 processed
# line 2189 processed
# line 2190 processed
# line 2191 processed
# line 2192 processed
# line 2193 processed
# line 2194 processed
# line 2195 processed
# line 2196 processed
# line 2197 processed
# line 2198 processed
# line 2199 processed
# line 2200 processed
# line 2201 processed
# line 2202 processed
# line 2203 processed
# line 2204 processed
# line 2205 processed
# line 2206 processed
# line 2207 processed
# line 2208 processed
# line 2209 processed
# line 2210 processed
# line 2211 processed
# line 2212 processed
# line 2213 processed
# line 2214 processed
# line 2215 processed
# line 2216 processed
# line 2217 processed
# line 2218 processed
# line 2219 processed
# line 2220 processed
# line 2221 processed
# line 2222 processed
# line 2223 processed
# line 2224 processed
# line 2225 processed
# line 2226 processed
# line 2227 processed
# line 2228 processed
# line 2229 processed
# line 2230 processed
# line 2231 processed
# line 2232 processed
# line 2233 processed
# line 2234 processed
# line 2235 processed
# line 2236 processed
# line 2237 processed
# line 2238 processed
# line 2239 processed
# line 2240 processed
# line 2241 processed
# line 2242 processed
# line 2243 processed
# line 2244 processed
# line 2245 processed
# line 2246 processed
# line 2247 processed
# line 2248 processed
# line 2249 processed
# line 2250 processed
# line 2251 processed
# line 2252 processed
# line 2253 processed
# line 2254 processed
# line 2255 processed
# line 2256 processed
# line 2257 processed
# line 2258 processed
# line 2259 processed
# line 2260 processed
# line 2261 processed
# line 2262 processed
# line 2263 processed
# line 2264 processed
# line 2265 processed
# line 2266 processed
# line 2267 processed
# line 2268 processed
# line 2269 processed
# line 2270 processed
# line 2271 processed
# line 2272 processed
# line 2273 processed
# line 2274 processed
# line 2275 processed
# line 2276 processed
# line 2277 processed
# line 2278 processed
# line 2279 processed
# line 2280 processed
# line 2281 processed
# line 2282 processed
# line 2283 processed
# line 2284 processed
# line 2285 processed
# line 2286 processed
# line 2287 processed
# line 2288 processed
# line 2289 processed
# line 2290 processed
# line 2291 processed
# line 2292 processed
# line 2293 processed
# line 2294 processed
# line 2295 processed
# line 2296 processed
# line 2297 processed
# line 2298 processed
# line 2299 processed
# line 2300 processed
# line 2301 processed
# line 2302 processed
# line 2303 processed
# line 2304 processed
# line 2305 processed
# line 2306 processed
# line 2307 processed
# line 2308 processed
# line 2309 processed
# line 2310 processed
# line 2311 processed
# line 2312 processed
# line 2313 processed
# line 2314 processed
# line 2315 processed
# line 2316 processed
# line 2317 processed
# line 2318 processed
# line 2319 processed
# line 2320 processed
# line 2321 processed
# line 2322 processed
# line 2323 processed
# line 2324 processed
# line 2325 processed
# line 2326 processed
# line 2327 processed
# line 2328 processed
# line 2329 processed
# line 2330 processed
# line 2331 processed
# line 2332 processed
# line 2333 processed
# line 2334 processed
# line 2335 processed
# line 2336 processed
# line 2337 processed
# line 2338 processed
# line 2339 processed
# line 2340 processed
# line 2341 processed
# line 2342 processed
# line 2343 processed
# line 2344 processed
# line 2345 processed
# line 2346 processed
# line 2347 processed
# line 2348 processed
# line 2349 processed
# line 2350 processed
# line 2351 processed
# line 2352 processed
# line 2353 processed
# line 2354 processed
# line 2355 processed
# line 2356 processed
# line 2357 processed
# line 2358 processed
# line 2359 processed
# line 2360 processed
# line 2361 processed
# line 2362 processed
# line 2363 processed
# line 2364 processed
# line 2365 processed
# line 2366 processed
# line 2367 processed
# line 2368 processed
# line 2369 processed
# line 2370 processed
# line 2371 processed
# line 2372 processed
# line 2373 processed
# line 2374 processed
# line 2375 processed
# line 2376 processed
# line 2377 processed
# line 2378 processed
# line 2379 processed
# line 2380 processed
# line 2381 processed
# line 2382 processed
# line 2383 processed
# line 2384 processed
# line 2385 processed
# line 2386 processed
# line 2387 processed
# line 2388 processed
# line 2389 processed
# line 2390 processed
# line 2391 processed
# line 2392 processed
# line 2393 processed
# line 2394 processed
# line 2395 processed
# line 2396 processed
# line 2397 processed
# line 2398 processed
# line 2399 processed
# line 2400 processed
# line 2401 processed
# line 2402 processed
# line 2403 processed
# line 2404 processed
# line 2405 processed
# line 2406 processed
# line 2407 processed
# line 2408 processed
# line 2409 processed
# line 2410 processed
# line 2411 processed
# line 2412 processed
# line 2413 processed
# line 2414 processed
# line 2415 processed
# line 2416 processed
# line 2417 processed
# line 2418 processed
# line 2419 processed
# line 2420 processed
# line 2421 processed
# line 2422 processed
# line 2423 processed
# line 2424 processed
# line 2425 processed
# line 2426 processed
# line 2427 processed
# line 2428 processed
# line 2429 processed
# line 2430 processed
# line 2431 processed
# line 2432 processed
# line 2433 processed
# line 2434 processed
# line 2435 processed
# line 2436 processed
# line 2437 processed
# ...
# line 24240 processed
# line 24241 processed
# line 24242 processed
# line 24243 processed
# line 24244 processed
# line 24245 processed
# line 24246 processed
# line 24247 processed
# line 24248 processed
# line 24249 processed
# line 24250 processed
# line 24251 processed
# line 24252 processed
# line 24253 processed
# line 24254 processed
# line 24255 processed
# line 24256 processed
# line 24257 processed
# line 24258 processed
# line 24259 processed
# line 24260 processed
# line 24261 processed
# line 24262 processed
# line 24263 processed
# line 24264 processed
# line 24265 processed
# line 24266 processed
# line 24267 processed
# line 24268 processed
# line 24269 processed
# line 24270 processed
# line 24271 processed
# line 24272 processed
# line 24273 processed
# line 24274 processed
# line 24275 processed
# line 24276 processed
# line 24277 processed
# line 24278 processed
# line 24279 processed
# line 24280 processed
# line 24281 processed
# line 24282 processed
# line 24283 processed
# line 24284 processed
# line 24285 processed
# line 24286 processed
# line 24287 processed
# line 24288 processed
# line 24289 processed
# line 24290 processed
# line 24291 processed
# line 24292 processed
# line 24293 processed
# line 24294 processed
# line 24295 processed
# line 24296 processed
# line 24297 processed
# line 24298 processed
# line 24299 processed
# line 24300 processed
# line 24301 processed
# line 24302 processed
# line 24303 processed
# line 24304 processed
# line 24305 processed
# line 24306 processed
# line 24307 processed
# line 24308 processed
# line 24309 processed
# line 24310 processed
# line 24311 processed
# line 24312 processed
# line 24313 processed
# line 24314 processed
# line 24315 processed
# line 24316 processed
# line 24317 processed
# line 24318 processed
# line 24319 processed
# line 24320 processed
# line 24321 processed
# line 24322 processed
# line 24323 processed
# line 24324 processed
# line 24325 processed
# line 24326 processed
# line 24327 processed
# line 24328 processed
# line 24329 processed
# line 24330 processed
# line 24331 processed
# line 24332 processed
# line 24333 processed
# line 24334 processed
# line 24335 processed
# line 24336 processed
# line 24337 processed
# line 24338 processed
# line 24339 processed
# line 24340 processed
# line 24341 processed
# line 24342 processed
# line 24343 processed
# line 24344 processed
# line 24345 processed
# line 24346 processed
# line 24347 processed
# line 24348 processed
# line 24349 processed
# line 24350 processed
# line 24351 processed
# line 24352 processed
# line 24353 processed
# line 24354 processed
# line 24355 processed
# line 24356 processed
# line 24357 processed
# line 24358 processed
# line 24359 processed
# line 24360 processed
# line 24361 processed
# line 24362 processed
# line 24363 processed
# line 24364 processed
# line 24365 processed
# line 24366 processed
# line 24367 processed
# line 24368 processed
# line 24369 processed
# line 24370 processed
# line 24371 processed
# line 24372 processed
# line 24373 processed
# line 24374 processed
# line 24375 processed
# line 24376 processed
# line 24377 processed
# line 24378 processed
# line 24379 processed
# line 24380 processed
# line 24381 processed
# line 24382 processed
# line 24383 processed
# line 24384 processed
# line 24385 processed
# line 24386 processed
# line 24387 processed
# line 24388 processed
# line 24389 processed
# line 24390 processed
# line 24391 processed
# line 24392 processed
# line 24393 processed
# line 24394 processed
# line 24395 processed
# line 24396 processed
# line 24397 processed
# line 24398 processed
# line 24399 processed
# line 24400 processed
# line 24401 processed
# line 24402 processed
# line 24403 processed
# line 24404 processed
# line 24405 processed
# line 24406 processed
# line 24407 processed
# line 24408 processed
# line 24409 processed
# line 24410 processed
# line 24411 processed
# line 24412 processed
# line 24413 processed
# line 24414 processed
# line 24415 processed
# line 24416 processed
# line 24417 processed
# line 24418 processed
# line 24419 processed
# line 24420 processed
# line 24421 processed
# line 24422 processed
# line 24423 processed
# line 24424 processed
# line 24425 processed
# line 24426 processed
# line 24427 processed
# line 24428 processed
# line 24429 processed
# line 24430 processed
# line 24431 processed
# line 24432 processed
# line 24433 processed
# line 24434 processed
# line 24435 processed
# line 24436 processed
# line 24437 processed
# line 24438 processed
# line 24439 processed
# line 24440 processed
# line 24441 processed
# line 24442 processed
# line 24443 processed
# line 24444 processed
# line 24445 processed
# line 24446 processed
# line 24447 processed
# line 24448 processed
# line 24449 processed
# line 24450 processed
# line 24451 processed
# line 24452 processed
# line 24453 processed
# line 24454 processed
# line 24455 processed
# line 24456 processed
# line 24457 processed
# line 24458 processed
# line 24459 processed
# line 24460 processed
# line 24461 processed
# line 24462 processed
# line 24463 processed
# line 24464 processed
# line 24465 processed
# line 24466 processed
# line 24467 processed
# line 24468 processed
# line 24469 processed
# line 24470 processed
# line 24471 processed
# line 24472 processed
# line 24473 processed
# line 24474 processed
# line 24475 processed
# line 24476 processed
# line 24477 processed
# line 24478 processed
# line 24479 processed
# line 24480 processed
# line 24481 processed
# line 24482 processed
# line 24483 processed
# line 24484 processed
# line 24485 processed
# line 24486 processed
# line 24487 processed
# line 24488 processed
# line 24489 processed
# line 24490 processed
# line 24491 processed
# line 24492 processed
# line 24493 processed
# line 24494 processed
# line 24495 processed
# line 24496 processed
# line 24497 processed
# line 24498 processed
# line 24499 processed
# line 24500 processed
# line 24501 processed
# line 24502 processed
# line 24503 processed
# line 24504 processed
# line 24505 processed
# line 24506 processed
# line 24507 processed
# line 24508 processed
# line 24509 processed
# line 24510 processed
# line 24511 processed
# line 24512 processed
# line 24513 processed
# line 24514 processed
# line 24515 processed
# line 24516 processed
# line 24517 processed
# line 24518 processed
# line 24519 processed
# line 24520 processed
# line 24521 processed
# line 24522 processed
# line 24523 processed
# line 24524 processed
# line 24525 processed
# line 24526 processed
# line 24527 processed
# line 24528 processed
# line 24529 processed
# line 24530 processed
# line 24531 processed
# line 24532 processed
# line 24533 processed
# line 24534 processed
# line 24535 processed
# line 24536 processed
# line 24537 processed
# line 24538 processed
# line 24539 processed
# line 24540 processed
# line 24541 processed
# line 24542 processed
# line 24543 processed
# line 24544 processed
# line 24545 processed
# line 24546 processed
# line 24547 processed
# line 24548 processed
# line 24549 processed
# line 24550 processed
# line 24551 processed
# line 24552 processed
# line 24553 processed
# line 24554 processed
# line 24555 processed
# line 24556 processed
# line 24557 processed
# line 24558 processed
# line 24559 processed
# line 24560 processed
# line 24561 processed
# line 24562 processed
# line 24563 processed
# line 24564 processed
# line 24565 processed
# line 24566 processed
# line 24567 processed
# line 24568 processed
# line 24569 processed
# line 24570 processed
# line 24571 processed
# line 24572 processed
# line 24573 processed
# line 24574 processed
# line 24575 processed
# line 24576 processed
# line 24577 processed
# line 24578 processed
# line 24579 processed
# line 24580 processed
# line 24581 processed
# line 24582 processed
# line 24583 processed
# line 24584 processed
# line 24585 processed
# line 24586 processed
# line 24587 processed
# line 24588 processed
# line 24589 processed
# line 24590 processed
# line 24591 processed
# line 24592 processed
# line 24593 processed
# line 24594 processed
# line 24595 processed
# line 24596 processed
# line 24597 processed
# line 24598 processed
# line 24599 processed
# line 24600 processed
# line 24601 processed
# line 24602 processed
# line 24603 processed
# line 24604 processed
# line 24605 processed
# line 24606 processed
# line 24607 processed
# line 24608 processed
# line 24609 processed
# line 24610 processed
# line 24611 processed
# line 24612 processed
# line 24613 processed
# line 24614 processed
# line 24615 processed
# line 24616 processed
# line 24617 processed
# line 24618 processed
# line 24619 processed
# line 24620 processed
# line 24621 processed
# line 24622 processed
# line 24623 processed
# line 24624 processed
# line 24625 processed
# line 24626 processed
# line 24627 processed
# line 24628 processed
# line 24629 processed
# line 24630 processed
# line 24631 processed
# line 24632 processed
# line 24633 processed
# line 24634 processed
# line 24635 processed
# line 24636 processed
# line 24637 processed
# line 24638 processed
# line 24639 processed
# line 24640 processed
# line 24641 processed
# line 24642 processed
# line 24643 processed
# line 24644 processed
# line 24645 processed
# line 24646 processed
# line 24647 processed
# line 24648 processed
# line 24649 processed
# line 24650 processed
# line 24651 processed
# line 24652 processed
# line 24653 processed
# line 24654 processed
# line 24655 processed
# line 24656 processed
# line 24657 processed
# line 24658 processed
# line 24659 processed
# line 24660 processed
# line 24661 processed
# line 24662 processed
# line 24663 processed
# line 24664 processed
# line 24665 processed
# line 24666 processed
# line 24667 processed
# line 24668 processed
# line 24669 processed
# line 24670 processed
# line 24671 processed
# line 24672 processed
# line 24673 processed
# line 24674 processed
# line 24675 processed
# line 24676 processed
# line 24677 processed
# line 24678 processed
# line 24679 processed
# line 24680 processed
# line 24681 processed
# line 24682 processed
# line 24683 processed
# line 24684 processed
# line 24685 processed
# line 24686 processed
# line 24687 processed
# line 24688 processed
# line 24689 processed
# line 24690 processed
# line 24691 processed
# line 24692 processed
# line 24693 processed
# line 24694 processed
# line 24695 processed
# line 24696 processed
# line 24697 processed
# line 24698 processed
# line 24699 processed
# line 24700 processed
# line 24701 processed
# line 24702 processed
# line 24703 processed
# line 24704 processed
# line 24705 processed
# line 24706 processed
# line 24707 processed
# line 24708 processed
# line 24709 processed
# line 24710 processed
# line 24711 processed
# line 24712 processed
# line 24713 processed
# line 24714 processed
# line 24715 processed
# line 24716 processed
# line 24717 processed
# line 24718 processed
# line 24719 processed
# line 24720 processed
# line 24721 processed
# line 24722 processed
# line 24723 processed
# line 24724 processed
# line 24725 processed
# line 24726 processed
# line 24727 processed
# line 24728 processed
# line 24729 processed
# line 24730 processed
# line 24731 processed
# line 24732 processed
# line 24733 processed
# line 24734 processed
# line 24735 processed
# line 24736 processed
# line 24737 processed
# line 24738 processed
# line 24739 processed
# line 24740 processed
# line 24741 processed
# line 24742 processed
# line 24743 processed
# line 24744 processed
# line 24745 processed
# line 24746 processed
# line 24747 processed
# line 24748 processed
# line 24749 processed
# line 24750 processed
# line 24751 processed
# line 24752 processed
# line 24753 processed
# line 24754 processed
# line 24755 processed
# line 24756 processed
# line 24757 processed
# line 24758 processed
# line 24759 processed
# line 24760 processed
# line 24761 processed
# line 24762 processed
# line 24763 processed
# line 24764 processed
# line 24765 processed
# line 24766 processed
# line 24767 processed
# line 24768 processed
# line 24769 processed
# line 24770 processed
# line 24771 processed
# line 24772 processed
# line 24773 processed
# line 24774 processed
# line 24775 processed
# line 24776 processed
# line 24777 processed
# line 24778 processed
# line 24779 processed
# line 24780 processed
# line 24781 processed
# line 24782 processed
# line 24783 processed
# line 24784 processed
# line 24785 processed
# line 24786 processed
# line 24787 processed
# line 24788 processed
# line 24789 processed
# line 24790 processed
# line 24791 processed
# line 24792 processed
# line 24793 processed
# line 24794 processed
# line 24795 processed
# line 24796 processed
# line 24797 processed
# line 24798 processed
# line 24799 processed
# line 24800 processed
# line 24801 processed
# line 24802 processed
# line 24803 processed
# line 24804 processed
# line 24805 processed
# line 24806 processed
# line 24807 processed
# line 24808 processed
# line 24809 processed
# line 24810 processed
# line 24811 processed
# line 24812 processed
# line 24813 processed
# line 24814 processed
# line 24815 processed
# line 24816 processed
# line 24817 processed
# line 24818 processed
# line 24819 processed
# line 24820 processed
# line 24821 processed
# line 24822 processed
# line 24823 processed
# line 24824 processed
# line 24825 processed
# line 24826 processed
# line 24827 processed
# line 24828 processed
# line 24829 processed
# line 24830 processed
# line 24831 processed
# line 24832 processed
# line 24833 processed
# line 24834 processed
# line 24835 processed
# line 24836 processed
# line 24837 processed
# line 24838 processed
# line 24839 processed
# line 24840 processed
# line 24841 processed
# line 24842 processed
# line 24843 processed
# line 24844 processed
# line 24845 processed
# line 24846 processed
# line 24847 processed
# line 24848 processed
# line 24849 processed
# line 24850 processed
# line 24851 processed
# line 24852 processed
# line 24853 processed
# line 24854 processed
# line 24855 processed
# line 24856 processed
# line 24857 processed
# line 24858 processed
# line 24859 processed
# line 24860 processed
# line 24861 processed
# line 24862 processed
# line 24863 processed
# line 24864 processed
# line 24865 processed
# line 24866 processed
# line 24867 processed
# line 24868 processed
# line 24869 processed
# line 24870 processed
# line 24871 processed
# line 24872 processed
# line 24873 processed
# line 24874 processed
# line 24875 processed
# line 24876 processed
# line 24877 processed
# line 24878 processed
# line 24879 processed
# line 24880 processed
# line 24881 processed
# line 24882 processed
# line 24883 processed
# line 24884 processed
# line 24885 processed
# line 24886 processed
# line 24887 processed
# line 24888 processed
# line 24889 processed
# line 24890 processed
# line 24891 processed
# line 24892 processed
# line 24893 processed
# line 24894 processed
# line 24895 processed
# line 24896 processed
# line 24897 processed
# line 24898 processed
# line 24899 processed
# line 24900 processed
# line 24901 processed
# line 24902 processed
# line 24903 processed
# line 24904 processed
# line 24905 processed
# line 24906 processed
# line 24907 processed
# line 24908 processed
# line 24909 processed
# line 24910 processed
# line 24911 processed
# line 24912 processed
# line 24913 processed
# line 24914 processed
# line 24915 processed
# line 24916 processed
# line 24917 processed
# line 24918 processed
# line 24919 processed
# line 24920 processed
# line 24921 processed
# line 24922 processed
# line 24923 processed
# line 24924 processed
# line 24925 processed
# line 24926 processed
# line 24927 processed
# line 24928 processed
# line 24929 processed
# line 24930 processed
# line 24931 processed
# line 24932 processed
# line 24933 processed
# line 24934 processed
# line 24935 processed
# line 24936 processed
# line 24937 processed
# line 24938 processed
# line 24939 processed
# line 24940 processed
# line 24941 processed
# line 24942 processed
# line 24943 processed
# line 24944 processed
# line 24945 processed
# line 24946 processed
# line 24947 processed
# line 24948 processed
# line 24949 processed
# line 24950 processed
# line 24951 processed
# line 24952 processed
# line 24953 processed
# line 24954 processed
# line 24955 processed
# line 24956 processed
# line 24957 processed
# line 24958 processed
# line 24959 processed
# line 24960 processed
# line 24961 processed
# line 24962 processed
# line 24963 processed
# line 24964 processed
# line 24965 processed
# line 24966 processed
# line 24967 processed
# line 24968 processed
# line 24969 processed
# line 24970 processed
# line 24971 processed
# line 24972 processed
# line 24973 processed
# line 24974 processed
# line 24975 processed
# line 24976 processed
# line 24977 processed
# line 24978 processed
# line 24979 processed
# line 24980 processed
# line 24981 processed
# line 24982 processed
# line 24983 processed
# line 24984 processed
# line 24985 processed
# line 24986 processed
# line 24987 processed
# line 24988 processed
# line 24989 processed
# line 24990 processed
# line 24991 processed
# line 24992 processed
# line 24993 processed
# line 24994 processed
# line 24995 processed
# line 24996 processed
# line 24997 processed
# line 24998 processed
# line 24999 processed
# line 25000 processed

# %% [markdown]
# First, we separate the text column into its own numpy array. Then, we convert the numpy array into a list. This puts our data into a universal list format for when we clean the data.
#
# Next, we initialize variables we need and start looping over the individual text descriptions.
#
# We start by using regular expressions to get rid of punctuation and symbols, and we also make all of the text lower case. This makes sure repeated words are recognized in our text.
#
# Next, we split our description string into words by splitting on the spaces between words. This allows us to modify individual words in our text.
#
# Then, we remove stop words from our text and stem all our words. Stop words are words such as "and", "the", and "of" which do not have a lot of sentimental value to our machine learning. You can think of it as removing noise. However, you have to be careful. Removing stop words on a dataset with short phrases such as "On the blue river" and "Over the mountain" can cause a loss of important information.
#
# When we stem all the words we are removing irrelevant part of words such as prefixes and suffixes which are similar. We use the Porter Stemmer, which is well known to be a good solution to stemming words. Stemming also tends to reduce the amount of words in our bag of words model later on, which can help lower the dimensionality of our input data. However, we need to be careful to not stem useful information like with removing stop words.
#
# Finally, we join the modified words back together with spaces and keep track of our progress.

# %% [markdown]
# Next, we will vectorize our text descriptions and add our text features back into our input data.

# %%
text_array = np.array(text_list)
data_array = data.values

tfidf = TfidfVectorizer()
text_vect = tfidf.fit_transform(text_array)

print(data_array.shape)
print(text_vect.shape)

full_data = np.concatenate((text_vect.toarray(), data_array), axis=1)

print(full_data.shape)
# Out:
# (25000, 1649)
# (25000, 16728)
# (25000, 18377)

# %% [markdown]
# First, we convert the main dataframe into a numpy array and the modified text list we made into a numpy array. Then, we use sklearn's term frequency vectorizer to vectorize our text data. Rather than simply counting the words in each description, we weight words based on term frequency. This vectorizer keeps less useful repeated words from overshadowing more useful unique words.
#
# Then, we append our vectorized text data onto our input data and observe the new shape of the data. The feature count may look very large compared to the number of examples. However, this is due to us having to cut down the number of examples from 150,000 to 25,000. The final feature count with 150,000 examples is only around 31,000, which suggests a good amount of repeated words.

# %% [markdown]
# You can find more information about tf-idf term weighting here: http://scikit-learn.org/stable/modules/feature_extraction.html

# %% [markdown]
# Next, we will split our data into train and test data concat the input data and labels together to fit EMADE's format.

# %%
X_train, X_test, y_train, y_test = train_test_split(full_data, labels.values, test_size=0.33)

data_train = np.concatenate((X_train, y_train), axis=1)
data_test = np.concatenate((X_test, y_test), axis=1)

print(data_train.shape)
print(data_test.shape)
# Out:
# (16750, 18378)
# (8250, 18378)

# %% [markdown]
# We split the data into training and test data with 67% as training and 33% as testing data. Then, we append the labels columns to the end of the input data columns to put the data into the format EMADE expects.

# %% [markdown]
# Next, we will test out the performance of our dataset on a logistic regression classifier to get a rough benchmark. Logistic Regression works well on text datasets and any datasets with a lot of discrete and/or Boolean (1,0) values.

# %%
classifier = LogisticRegression()

classifier.fit(X_train, np.ravel(y_train))

predicted = classifier.predict(X_test)

print("Classification report for classifier %s:\n%s\n"
      % (classifier, metrics.classification_report(y_test, predicted)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(y_test, predicted))
# Out:
# Classification report for classifier LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False):
#              precision    recall  f1-score   support
#
#         0.0       0.89      0.96      0.93      6804
#         1.0       0.72      0.46      0.56      1446
#
# avg / total       0.86      0.87      0.86      8250
#
#
# Confusion matrix:
# [[6547  257]
#  [ 785  661]]

# %% [markdown]
# Next, we will convert our train and test data back into pandas dataframes and export it in the proper format for EMADE.

# %%
train = pd.DataFrame(data_train)
test = pd.DataFrame(data_test)

divisor_train = math.ceil(len(train) / 5)
divisor_test = math.ceil(len(test) / 5)

count = 0
for g, df in train.groupby(np.arange(len(train)) // divisor_train):
    print(df.shape)

    np.savetxt("datasets/wine_data_set_train_%i.txt" % count, df.values, fmt='%.5f', delimiter=",")

    with open("datasets/wine_data_set_train_%i.txt" % count, "rb") as f_in, gzip.open("datasets/wine_data_set_train_%i.dat.gz" % count, "wb") as f_out:
        shutil.copyfileobj(f_in, f_out)
        
    os.remove("datasets/wine_data_set_train_%i.txt" % count)

    count += 1
    
count = 0
for g, df in test.groupby(np.arange(len(test)) // divisor_test):
    print(df.shape)

    np.savetxt("datasets/wine_data_set_test_%i.txt" % count, df.values, fmt='%.5f', delimiter=",")

    with open("datasets/wine_data_set_test_%i.txt" % count, "rb") as f_in, gzip.open("datasets/wine_data_set_test_%i.dat.gz" % count, "wb") as f_out:
        shutil.copyfileobj(f_in, f_out)
        
    os.remove("datasets/wine_data_set_test_%i.txt" % count)

    count += 1
    
small_train = train.drop(train.index[1675:])
small_test = test.drop(test.index[825:])

np.savetxt("datasets/wine_data_set_train_small.txt", small_train.values, fmt='%.5f', delimiter=",")

with open("datasets/wine_data_set_train_small.txt", "rb") as f_in, gzip.open("datasets/wine_data_set_train_small.dat.gz", "wb") as f_out:
    shutil.copyfileobj(f_in, f_out)
    
os.remove("datasets/wine_data_set_train_small.txt")
              
np.savetxt("datasets/wine_data_set_test_small.txt", small_train.values, fmt='%.5f', delimiter=",")

with open("datasets/wine_data_set_test_small.txt", "rb") as f_in, gzip.open("datasets/wine_data_set_test_small.dat.gz", "wb") as f_out:
    shutil.copyfileobj(f_in, f_out)
    
os.remove("datasets/wine_data_set_test_small.txt")
# Out:
# (3350, 18378)
# (3350, 18378)
# (3350, 18378)
# (3350, 18378)
# (3350, 18378)
# (1650, 18378)
# (1650, 18378)
# (1650, 18378)
# (1650, 18378)
# (1650, 18378)

# %% [markdown]
# We split the dataset into 5 chunks each with 20% of the data. Then, we set aside one chunk of 10% to be our small dataset in EMADE.
#
# The final step for preprocessing is to compress all the .dat files into .dat.gz files and place them in a folder under the datasets directory of EMADE.
#
# There are other datasets already implemented into EMADE in this format.

# %% [markdown]
# # XML Formatting

# %% [markdown]
# Below is an example xml template for the dataset we preprocessed. This template is used to setup parameters for EMADE. You can change the objectives, crossover probability, and mutation probability from here.
#
# Make sure to make an xml file and store it in the templates directory when you implement a new dataset into EMADE.

# %% [markdown]
# ## Note: Do NOT run the code cell below

# %%
<?xml version="1.0"?>

<input>

    <datasets>
        <dataset>
            <name>SmallDataSet</name>
            <type>featuredata</type>
            <MonteCarlo>
                <trial>
                    <trainFilename>datasets/wine/wine_data_set_train_small.dat.gz</trainFilename>
                    <testFilename>datasets/wine/wine_data_set_test_small.dat.gz</testFilename>
                </trial>
            </MonteCarlo>
        </dataset>
        <dataset>
            <name>FullDataSet</name>
            <type>featuredata</type>
            <MonteCarlo>
                <trial>
                    <trainFilename>datasets/wine/wine_data_set_train_0.dat.gz</trainFilename>
                    <testFilename>datasets/wine/wine_data_set_test_0.dat.gz</testFilename>
                </trial>
                <trial>
                    <trainFilename>datasets/wine/wine_data_set_train_1.dat.gz</trainFilename>
                    <testFilename>datasets/wine/wine_data_set_test_1.dat.gz</testFilename>
                </trial>
                <trial>
                    <trainFilename>datasets/wine/wine_data_set_train_2.dat.gz</trainFilename>
                    <testFilename>datasets/wine/wine_data_set_test_2.dat.gz</testFilename>
                </trial>
                <trial>
                    <trainFilename>datasets/wine/wine_data_set_train_3.dat.gz</trainFilename>
                    <testFilename>datasets/wine/wine_data_set_test_3.dat.gz</testFilename>
                </trial>
                <trial>
                    <trainFilename>datasets/wine/wine_data_set_train_4.dat.gz</trainFilename>
                    <testFilename>datasets/wine/wine_data_set_test_4.dat.gz</testFilename>
                </trial>
            </MonteCarlo>
        </dataset>
    </datasets>

    <objectives>
        <objective>
            <name>False Positives</name>
            <weight>-1.0</weight>
            <achievable>4971.8</achievable>
            <goal>0</goal>
            <evaluationFunction>false_positive</evaluationFunction>
            <lower>0</lower>
            <upper>1</upper>
        </objective>
        <objective>
            <name>False Negatives</name>
            <weight>-1.0</weight>
            <achievable>1541.2</achievable>
            <goal>0</goal>
            <evaluationFunction>false_negative</evaluationFunction>
            <lower>0</lower>
            <upper>1</upper>
        </objective>
        <objective>
            <name>F1-Score</name>
            <weight>-1.0</weight>
            <achievable>0.2</achievable>
            <goal>0</goal>
            <evaluationFunction>f1_score_min</evaluationFunction>
            <lower>0</lower>
            <upper>1</upper>
        </objective>
        <objective>
            <name>Num Elements</name>
            <weight>-1.0</weight>
            <achievable>100.0</achievable>
            <goal>0</goal>
            <evaluationFunction>num_elements_eval_function</evaluationFunction>
            <lower>0</lower>
            <upper>1</upper>
        </objective>

    </objectives>

    <evaluation>
        <module>evalFunctions</module>
        <memoryLimit>30</memoryLimit> <!-- In Percent -->
    </evaluation>

    <scoopParameters>
        <host>
            <name>localhost</name>
            <workers>24</workers>
        </host>
        <!--<host>
            <name>localhost</name>
            <workers>3</workers>
        </host>
        <host>
            <name>localhost</name>
            <workers>3</workers>
        </host>
        <host>
            <name>localhost</name>
            <workers>3</workers>
        </host>
        <host>
            <name>localhost</name>
            <workers>3</workers>
        </host>
        <host>
            <name>localhost</name>
            <workers>3</workers>
        </host>-->
    </scoopParameters>

    <evolutionParameters>
        <initialPopulationSize>512</initialPopulationSize>
        <elitePoolSize>512</elitePoolSize>
        <launchSize>300</launchSize>
        <minQueueSize>200</minQueueSize>

        <matings>
            <mating>
                <name>crossover</name>
                <probability>0.50</probability>
            </mating>
            <mating>
                <name>crossoverEphemeral</name>
                <probability>0.50</probability>
            </mating>
            <mating>
                <name>headlessChicken</name>
                <probability>0.10</probability>
            </mating>
            <mating>
                <name>headlessChickenEphemeral</name>
                <probability>0.10</probability>
            </mating>
        </matings>

        <mutations>
            <mutation>
                <name>insert</name>
                <probability>0.05</probability>
            </mutation>
            <mutation>
                <name>insert modify</name>
                <probability>0.10</probability>
            </mutation>
            <mutation>
                <name>ephemeral</name>
                <probability>0.25</probability>
            </mutation>
            <mutation>
                <name>node replace</name>
                <probability>0.05</probability>
            </mutation>
            <mutation>
                <name>uniform</name>
                <probability>0.05</probability>
            </mutation>
            <mutation>
                <name>shrink</name>
                <probability>0.05</probability>
            </mutation>
        </mutations>

        <selections>
            <selection>
                <name>NSGA2</name>
            </selection>
        </selections>

    </evolutionParameters>

    <seedFile>

    </seedFile>

    <genePoolFitness>
        <prefix>genePoolFitnessWine</prefix>
    </genePoolFitness>
    <paretoFitness>
        <prefix>paretoFitnessWine</prefix>
    </paretoFitness>
    <parentsOutput>
        <prefix>parentsWine</prefix>
    </parentsOutput>



    <paretoOutput>
        <prefix>paretoFrontWine</prefix>
    </paretoOutput>
</input>
# Out:
#   File "<ipython-input-11-ef8ab20c933c>", line 1
#     <?xml version="1.0"?>
#     ^
# SyntaxError: invalid syntax

# %%
import nltk

# %%
nltk.download()
